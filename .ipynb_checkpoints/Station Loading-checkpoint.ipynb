# %%
import simpy
import random
import matplotlib.pyplot as plt
import numpy as np



train_capacity = 800;
platform_capacity = 1000;


train_arrive_time = 5;
train_leave_time = 5;


offload_rate = 50; #people per second
load_rate = 50; #people per second

onboard_range = [round(train_capacity/3), train_capacity];
offload_range = [0, train_capacity/3];

class Station:
    def __init__ (self, env):
        self.station = simpy.Resource(env, capacity = 1)
        self.platform = simpy.Container(env, capacity = platform_capacity, init = 0)
        self.platformdata=[];
        self.traindata =[[0,0]];

class Train(object):
    def __init__(self, env, station, onboard, num_to_offload):
        self.env=env
        self.capacity = train_capacity;
        self.onboard = onboard;
        self.num_to_offload = num_to_offload;
        
        #start run process
        self.action = env.process(self.run(station))
        
    def run(self, station):
        print('T: %.1f - Train arriving with %d passengers' %  (env.now, self.onboard))
        station.traindata.append([env.now, np.nan])
        station.traindata.append([env.now, self.onboard])
        
        with station.station.request() as req:
            yield req
            station.traindata.append([env.now, self.onboard])
            yield (env.timeout(train_arrive_time))
            print('T: %.1f - Train entered with %d passengers' % (env.now,self.onboard))
            station.traindata.append([env.now, self.onboard])
            
            #off load people
            yield env.process(self.offload(station))
            station.traindata.append([env.now, self.onboard])
            
            #load people
            yield env.process(self.load(station))
            station.traindata.append([env.now, self.onboard])
            
            
            #mark the exit of the train
            station.traindata.append([env.now+train_leave_time, self.onboard])
            station.traindata.append([env.now+train_leave_time, np.nan])

            yield self.env.timeout(train_leave_time)
            print('T: %.1f - Train leaving with %d passengers' % (env.now,self.onboard))
            #station.traindata.append([env.now, self.onboard])
            
    def offload(self, station):
        print('T: %.1f - Train offloading %d people' %  (env.now, self.num_to_offload))
        self.onboard -= self.num_to_offload;        
        yield self.env.timeout(self.num_to_offload/offload_rate)
        
    def load(self, station):
        #the number of people that can be loaded is either everyone at the station
        #or all the way till the capacity is used up
        num_to_load = min(station.platform.level, self.capacity - self.onboard);
        
        print('T: %.1f - Train loading %d people' %  (env.now, num_to_load))
        self.onboard += num_to_load;
        station.platform.get(num_to_load)
        yield self.env.timeout(num_to_load/load_rate)

def train_generator(env, station, onboard_range, offload_range):
    while True:
        onboard = random.randint(*onboard_range)
        offload = random.randint(0, onboard)
        train = Train(env, station1, onboard, offload)
        #wait for some time
        yield env.timeout(random.gauss(90,10))

def passenger_generator(env, station):
    while True:
        #add between 1 and 6 passengers
        station.platform.put(random.randint(1,1))
        station.platformdata.append([env.now, station.platform.level])
        #wait for some time
        yield env.timeout(random.expovariate(1/(1/4)))

def monitor(env, station):
    while True:
        print('T: %.1f - Platform: %d' % (env.now, station.platform.level))
        yield(env.timeout(0.5))

# %%
sim_time = 15*60;
#create simulation
env = simpy.Environment()
#create station
station1 = Station(env)

env.process(train_generator(env, station1, onboard_range, offload_range))
env.process(passenger_generator(env, station1))
#env.process(monitor(env, station1))
env.run(until=sim_time)

station1.traindata.append([sim_time,station1.traindata[-1][1]])



plt.scatter(*zip(*station1.platformdata))
plt.xlabel('time (s)')
plt.ylabel('Platform Occupancy')
plt.ylim([0,platform_capacity])


plt.plot(*zip(*station1.traindata),color='r')
plt.xlabel('time (s)')
#plt.ylabel('Train occupancy')
#plt.ylim([0,train_capacity])


plt.show()
# Out:
# T: 0.0 - Train arriving with 368 passengers
# T: 5.0 - Train entered with 368 passengers
# T: 5.0 - Train offloading 122 people
# T: 7.4 - Train loading 21 people
# T: 12.9 - Train leaving with 267 passengers
# T: 85.8 - Train arriving with 366 passengers
# T: 90.8 - Train entered with 366 passengers
# T: 90.8 - Train offloading 32 people
# T: 91.5 - Train loading 313 people
# T: 102.7 - Train leaving with 647 passengers
# T: 192.9 - Train arriving with 335 passengers
# T: 197.9 - Train entered with 335 passengers
# T: 197.9 - Train offloading 97 people
# T: 199.9 - Train loading 432 people
# T: 213.5 - Train leaving with 670 passengers
# T: 283.5 - Train arriving with 346 passengers
# T: 288.5 - Train entered with 346 passengers
# T: 288.5 - Train offloading 71 people
# T: 289.9 - Train loading 341 people
# T: 301.7 - Train leaving with 616 passengers
# T: 365.9 - Train arriving with 317 passengers
# T: 370.9 - Train entered with 317 passengers
# T: 370.9 - Train offloading 157 people
# T: 374.0 - Train loading 342 people
# T: 385.8 - Train leaving with 502 passengers
# T: 480.6 - Train arriving with 625 passengers
# T: 485.6 - Train entered with 625 passengers
# T: 485.6 - Train offloading 498 people
# T: 495.5 - Train loading 485 people
# T: 510.2 - Train leaving with 612 passengers
# T: 563.6 - Train arriving with 691 passengers
# T: 568.6 - Train entered with 691 passengers
# T: 568.6 - Train offloading 163 people
# T: 571.9 - Train loading 272 people
# T: 582.3 - Train leaving with 800 passengers
# T: 650.6 - Train arriving with 363 passengers
# T: 655.6 - Train entered with 363 passengers
# T: 655.6 - Train offloading 176 people
# T: 659.1 - Train loading 392 people
# T: 672.0 - Train leaving with 579 passengers
# T: 739.2 - Train arriving with 623 passengers
# T: 744.2 - Train entered with 623 passengers
# T: 744.2 - Train offloading 197 people
# T: 748.2 - Train loading 330 people
# T: 759.8 - Train leaving with 756 passengers
# T: 826.5 - Train arriving with 495 passengers
# T: 831.5 - Train entered with 495 passengers
# T: 831.5 - Train offloading 118 people
# T: 833.8 - Train loading 348 people
# T: 845.8 - Train leaving with 725 passengers

# %%
plt.scatter(*zip(*station1.platformdata))
plt.xlabel('time (s)')
plt.ylabel('Platform Occupancy')
plt.ylim([0,platform_capacity])


plt.plot(*zip(*station1.traindata),color='r')
plt.xlabel('time (s)')
#plt.ylabel('Train occupancy')
#plt.ylim([0,train_capacity])

plt.xlim([350,390])
plt.show()
